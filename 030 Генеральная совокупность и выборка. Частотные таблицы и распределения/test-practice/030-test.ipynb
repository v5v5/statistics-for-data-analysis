# %%
import pandas as pd

# %%
df = pd.read_excel('../../data/MarvelComicCaracters.xlsx')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16376 entries, 0 to 16375
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              16376 non-null  object
#  1   align             13564 non-null  object
#  2   eye               6609 non-null   object
#  3   hair              9989 non-null   object
#  4   sex               15522 non-null  object
#  5   appearances       15280 non-null  float64
#  6   first_appearance  15561 non-null  float64
# dtypes: float64(2), object(5)
# memory usage: 895.7+ KB

# %% [markdown]
# Какой тип графика из перечисленных наиболее удобен для описания распределения переменной appearances? Выберите один верный ответ.

# %%
import matplotlib.pyplot as plt
df['appearances'].hist(bins=3)
# Out:
# <AxesSubplot:>

# %% [markdown]
# По переменной align была построена частотная таблица. Укажите, какие ошибки были допущены в таблице. Чтобы проверить ее, постройте таблицу сами, используя удобную вам программу. Выберите один верный ответ.

# %%
df['align'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Определите три наиболее часто встречающих цвета глаз персонажей, выберите из данных только их и заполните частотную таблицу по переменной eye. В вариантах ответов представлены числа, которые могут быть записаны в таблицу. Выберите один верный ответ.

# %%
df['eye'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Укажите, верно ли следующее утверждение: у мужских персонажей чаще всего встречаются темно-карие глаза.

# %%
df[df['sex'] == 'Мужской персонаж'].groupby('eye').size()
# Out:
# eye
# Белые глаза               292
# Голубые глаза            1258
# Желтые глаза              174
# Желтые глазные яблоки       4
# Зеленые глаза             328
# Золотые глаза              10
# Карие глаза                58
# Красные глаза             377
# Лиловые глаза               3
# Много глаз                  6
# Нет глаз                    3
# Один глаз                  20
# Оранжевые глаза            18
# Разноцветные глаза         28
# Розовые глаза              15
# Серебристые глаза           4
# Серые глаза                75
# Темно-карие глаза        1400
# Фасеточные глаза            1
# Фиолетовые глаза           15
# Черные глаза              394
# Черные глазные яблоки       1
# Янтарные глаза              8
# dtype: int64

# %%
df[df['sex'] == 'Мужской персонаж']['eye'].value_counts()
# Out:
# Темно-карие глаза        1400
# Голубые глаза            1258
# Черные глаза              394
# Красные глаза             377
# Зеленые глаза             328
# Белые глаза               292
# Желтые глаза              174
# Серые глаза                75
# Карие глаза                58
# Разноцветные глаза         28
# Один глаз                  20
# Оранжевые глаза            18
# Розовые глаза              15
# Фиолетовые глаза           15
# Золотые глаза              10
# Янтарные глаза              8
# Много глаз                  6
# Серебристые глаза           4
# Желтые глазные яблоки       4
# Нет глаз                    3
# Лиловые глаза               3
# Черные глазные яблоки       1
# Фасеточные глаза            1
# Name: eye, dtype: int64

# %% [markdown]
# Постройте частотную таблицу для персонажей женского пола по переменной eye. У скольких из них золотые глаза? Введите ответ в виде целого числа.

# %%
df[df['sex'] == 'Женский персонаж']['eye'].value_counts()
# Out:
# Голубые глаза            692
# Темно-карие глаза        519
# Зеленые глаза            268
# Черные глаза             137
# Белые глаза               82
# Красные глаза             77
# Желтые глаза              57
# Серые глаза               20
# Карие глаза               17
# Фиолетовые глаза          14
# Лиловые глаза              8
# Разноцветные глаза         7
# Серебристые глаза          6
# Розовые глаза              5
# Оранжевые глаза            5
# Золотые глаза              3
# Янтарные глаза             2
# Желтые глазные яблоки      2
# Черные глазные яблоки      2
# Пурпурные глаза            2
# Нет глаз                   1
# Много глаз                 1
# Один глаз                  1
# Name: eye, dtype: int64

# %% [markdown]
# Сколько раз появлялся добрый персонаж с пурпурными глазами? Введите ответ в виде целого числа.

# %%
df[(df['align'] == 'Добрый персонаж') & (df['eye'] == 'Пурпурные глаза')]
# Out:
#                        name            align              eye  \
# 1729  Fireflyte (Earth-616)  Добрый персонаж  Пурпурные глаза
#
#                   hair               sex  appearances  first_appearance
# 1729  Пурпурные волосы  Женский персонаж         21.0            1981.0

# %%
df[df['align'] == 'Добрый персонаж']['eye'].value_counts()
# Out:
# Голубые глаза            860
# Темно-карие глаза        773
# Зеленые глаза            188
# Черные глаза             153
# Белые глаза              107
# Красные глаза             69
# Желтые глаза              41
# Серые глаза               26
# Карие глаза               25
# Розовые глаза             10
# Разноцветные глаза         6
# Фиолетовые глаза           5
# Оранжевые глаза            5
# Золотые глаза              5
# Серебристые глаза          4
# Один глаз                  4
# Лиловые глаза              4
# Черные глазные яблоки      2
# Желтые глазные яблоки      2
# Много глаз                 2
# Пурпурные глаза            1
# Янтарные глаза             1
# Name: eye, dtype: int64

# %% [markdown]
# Были выбраны самые часто встречающиеся цвета глаз персонажей. Далее, только по этим данным, построена столбчатая диаграмма. Что можно сказать, основываясь только на графике? Выберите один верный ответ.

# %%
df.groupby('eye')['align'].value_counts().unstack().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='eye'>

# %% [markdown]
# Укажите, верно ли следующее утверждение: больше всего персонажей в первый раз появилось в 1993 году.

# %%
df.groupby('first_appearance').size().reset_index(name='sum').sort_values(['sum'], ascending=False)
# Out:
#     first_appearance  sum
# 54            1993.0  554
# 55            1994.0  485
# 53            1992.0  455
# 67            2006.0  381
# 52            1991.0  360
# ..               ...  ...
# 13            1952.0   26
# 17            1956.0   16
# 18            1957.0    7
# 20            1959.0    4
# 19            1958.0    2
#
# [75 rows x 2 columns]

# %% [markdown]
# Сколько процентов (от общего числа персонажей) составляют мужские персонажи, которые появлялись больше 100 раз? В ответ запишите число (процент от 0 до 100), округлите до целого.

# %%
len(df[(df['sex'] == "Мужской персонаж") & (df['appearances'] > 100)]) / len(df) * 100
# Out:
# 1.6914997557401075
