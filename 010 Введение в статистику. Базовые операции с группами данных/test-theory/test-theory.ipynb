# %%
import pandas as pd

# %%
df = pd.read_excel('../../data/StarWars.xlsx')
df.head()
# Out:
#    respondentID seen  fan gender age_group             income  \
# 0    3292879998   да   да      М     18-29                NaN
# 1    3292879538  нет  NaN      М     18-29         0 - 24.999
# 2    3292765271   да  нет      М     18-29         0 - 24.999
# 3    3292763116   да   да      М     18-29  100.000 - 149.999
# 4    3292731220   да   да      М     18-29  100.000 - 149.999
#
#                            loc                      yoda princess_leia_organa
# 0           Южно-Атлантический            очень нравится       очень нравится
# 1     Юго-Западный центральный                       NaN                  NaN
# 2  Северо-Западный центральный  не знаю такого персонажа             нравится
# 3  Северо-Западный центральный            очень нравится       очень нравится
# 4  Северо-Западный центральный                  нравится             нравится

# %%
df[(df['age_group']=='18-29') & (df['fan']=='нет')].groupby('loc').count()
# Out:
#                               respondentID  seen  fan  gender  age_group  \
# loc
# Горный                                   4     4    4       4          4
# Новая Англия                             5     5    5       5          5
# Северо-Восточный центральный             6     6    6       6          6
# Северо-Западный центральный              6     6    6       6          6
# Средне-Атлантический                     5     5    5       5          5
# Тихоокеанский                           19    19   19      19         19
# Юго-Восточный центральный                3     3    3       3          3
# Юго-Западный центральный                 4     4    4       4          4
# Южно-Атлантический                       4     4    4       4          4
#
#                               income  yoda  princess_leia_organa
# loc
# Горный                             4     3                     3
# Новая Англия                       4     5                     5
# ...

# %%
df.groupby('loc').count()
# Out:
#                               respondentID  seen  fan  gender  age_group  \
# loc
# Горный                                  79    79   68      79         79
# Новая Англия                            75    75   60      75         75
# Северо-Восточный центральный           181   181  134     181        181
# Северо-Западный центральный             93    93   76      93         93
# Средне-Атлантический                   122   122   93     122        122
# Тихоокеанский                          175   175  146     175        175
# Юго-Восточный центральный               38    38   32      38         38
# Юго-Западный центральный               110   110   76     110        110
# Южно-Атлантический                     170   170  133     170        170
#
#                               income  yoda  princess_leia_organa
# loc
# Горный                            67    67                    67
# Новая Англия                      62    59                    59
# ...

# %%
df[df['yoda'].isna()].shape
# Out:
# (360, 9)

# %%
df[(df['loc']=='Новая Англия') & (df['princess_leia_organa']=='очень нравится')].shape
# Out:
# (39, 9)
