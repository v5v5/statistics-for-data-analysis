# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('../../data/UrbanizationCensusTract.xlsx')

# %%
df
# Out:
#        statefips        state         gisjoin           lat_tract  long_tract  \
# 0              1      Alabama  G0100010020100            32.47718   -86.49007
# 1              1      Alabama  G0100010020200            32.47425   -86.47337
# 2              1      Alabama  G0100010020300  32.475429999999996   -86.46019
# 3              1      Alabama  G0100010020400              32.472   -86.44363
# 4              1      Alabama  G0100010020500            32.45883   -86.42266
# ...          ...          ...             ...                 ...         ...
# 73275         72  Puerto Rico  G7201530750501            18.03124   -66.86725
# 73276         72  Puerto Rico  G7201530750502            18.02477   -66.86044
# 73277         72  Puerto Rico  G7201530750503  18.025270000000003   -66.87763
# 73278         72  Puerto Rico  G7201530750601            18.01738   -66.83936
# 73279         72  Puerto Rico  G7201530750602            17.98674   -66.85192
#
# ...

# %%
df['urbanindex_float'] = pd.to_numeric(df['urbanindex'], errors='coerce')

# %% [markdown]
# Какой график лучше всех подойдет для визуализации распределения переменной urbanindex? Выберите один верный ответ.

# %%
df.hist('urbanindex_float', bins=100)
# Out:
# array([[<AxesSubplot:title={'center':'urbanindex_float'}>]], dtype=object)

# %% [markdown]
# Укажите, верно ли следующее утверждение: для определения выбросов и аномальных значений в переменной population подойдет ящик с усами.

# %%
data = df['population']
fig1, ax1 = plt.subplots()
ax1.set_title('Population')
ax1.boxplot(data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x26b5aa3f3d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x26b5aa3faf0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x26b5aa3f040>],
#  'medians': [<matplotlib.lines.Line2D at 0x26b5aa46250>],
#  'fliers': [<matplotlib.lines.Line2D at 0x26b5aa465e0>],
#  'means': []}

# %% [markdown]
# Укажите, верно ли следующее утверждение: для визуализации распределения числа жителей каждого переписного района Аляски лучше всего подойдет гистограмма.

# %%
df[df['state'] == 'Alaska']['population'].hist(bins=100)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Постройте ящики с усами для каждого из указанных штатов по переменной urbanindex. Выберите штат, в котором нет выбросов по данной переменной. Выберите один верный ответ.

# %%
df
# Out:
#        statefips        state         gisjoin           lat_tract  long_tract  \
# 0              1      Alabama  G0100010020100            32.47718   -86.49007
# 1              1      Alabama  G0100010020200            32.47425   -86.47337
# 2              1      Alabama  G0100010020300  32.475429999999996   -86.46019
# 3              1      Alabama  G0100010020400              32.472   -86.44363
# 4              1      Alabama  G0100010020500            32.45883   -86.42266
# ...          ...          ...             ...                 ...         ...
# 73275         72  Puerto Rico  G7201530750501            18.03124   -66.86725
# 73276         72  Puerto Rico  G7201530750502            18.02477   -66.86044
# 73277         72  Puerto Rico  G7201530750503  18.025270000000003   -66.87763
# 73278         72  Puerto Rico  G7201530750601            18.01738   -66.83936
# 73279         72  Puerto Rico  G7201530750602            17.98674   -66.85192
#
# ...

# %%
data_california = df[df['state'] == 'California']['urbanindex_float']
data_nebraska = df[df['state'] == 'Nebraska']['urbanindex_float']
data_arizona = df[df['state'] == 'Arizona']['urbanindex_float']
data_texas = df[df['state'] == 'Texas']['urbanindex_float']

data_california.plot(kind='box', title='California')
plt.show()
data_nebraska.plot(kind='box', title='Nebraska')
plt.show()
data_arizona.plot(kind='box', title='Arizona')
plt.show()
data_texas.plot(kind='box', title='Texas')
plt.show()

# %%
# fig, ax = plt.subplots(1, 1, sharex=True, figsize=(15,10))
sns.boxplot(y=data_nebraska)
# Out:
# <AxesSubplot:ylabel='urbanindex_float'>

# %% [markdown]
# Постройте тепловую карту по переменным population, adj_radiuspop_5 и urbanindex. Какой вывод можно сделать на основе полученных данных? Выберите один верный ответ.

# %%
cols_num = ['population', 'adj_radiuspop_5', 'urbanindex_float']
correlation = df.corr().loc[cols_num, cols_num]

# %%
fig , ax = plt.subplots(figsize = (5,4))

sns.heatmap(correlation, 
            linewidths=0.5, annot=True,cmap='viridis',
            linecolor="white", annot_kws = {'size':12})
# Out:
# <AxesSubplot:>

# %% [markdown]
# Посмотрите на штаты Аляска (Alaska), Оклахома (Oklahoma), Северная Дакота (North Dakota) и Монтана (Montana). Сколько из указанных штатов не содержат выбросы по переменной population? Попробуйте построить ящики с усами для каждого штата и ответить на вопрос. Введите ответ в виде целого числа.

# %%
data_alaska = df[df['state'] == 'Alaska']['population']
data_oklahoma = df[df['state'] == 'Oklahoma']['population']
data_north_dakota = df[df['state'] == 'North Dakota']['population']
data_montana = df[df['state'] == 'Montana']['population']

data_alaska.plot(kind='box', title='Alaska')
plt.show()
data_oklahoma.plot(kind='box', title='Oklahoma')
plt.show()
data_north_dakota.plot(kind='box', title='North Dakota')
plt.show()
data_montana.plot(kind='box', title='Montana')
plt.show()

# %% [markdown]
# Постройте гистограмму для переменной urbanindex в штате Оклахома. Укажите, верно ли следующее утверждение: в штате Оклахома (Oklahoma) переменная urbanindex распределена нормально.

# %%
df[df['state']=='Oklahoma']['urbanindex_float'].hist(bins=100)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Укажите, верно ли следующее утверждение: при построении ящика с усами для Канзаса (Kansas) и Кентукки (Kentucky) по переменной urbanindex мы увидим одинаковое количество выбросов.

# %%
data_kansas = df[df['state'] == 'Kansas']['urbanindex_float']
data_kentucky = df[df['state'] == 'Kentucky']['urbanindex_float']

data_kansas.plot(kind='box', title='Alaska')
plt.show()
data_kentucky.plot(kind='box', title='Oklahoma')
plt.show()

# %% [markdown]
# Постройте тепловую карту и определите, в каком штате сильнее всего коррелируют показатели population и adj_radiuspop_5? В ответ запишите номер штата (согласно столбцу statefips).

# %%
df_statefips = df.groupby('statefips')[['population', 'adj_radiuspop_5']].corr()

# %%
fig , ax = plt.subplots(figsize = (24,22))
sns.heatmap(df_statefips, 
            linewidths=0.5, annot=True,cmap='viridis',
            linecolor="white", annot_kws = {'size':12})
# Out:
# <AxesSubplot:ylabel='statefips-None'>
